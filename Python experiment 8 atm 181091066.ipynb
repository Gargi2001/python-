# %%
print("Welcome!")
class atm:
    def accname(new,name):
        new.name=name
        
    def accdetails(new):
        print('Bank Account Details: ')
        print('Name of Account Holder: ', name)
        print('Account Number: ', bank[name][0])
        print('Phone Number: ', bank[name][1])
        
    def pin(new):
            p=int(input('Enter previous PIN: '))
            if p==bank[name][3]:
                a=int(input('Enter new PIN: '))
                b=int(input("Confirm new PIN:"))
                bank[name][3]=b
                        
    def balance(new):
        print('Account Balance(in Rupees): ',bank[name][2])
        
    def withdrawal(new):
        print('Account Balance(in Rupees): ',bank[name][2])
        amount =float(input('Enter withdrawal amount: '))  
        if amount<= bank[name][2]:
            bank[name][2]=bank[name][2]-amount
            print('New Account Balance: ', bank[name][2])
        else:
            print('Insufficient Balance in Account!')

    def deposit(new):
        deposit=float(input('Enter amount to Deposit: '))
        bank[name][2]=bank[name][2]+deposit
        print(' Account Balance: ', name[name][2])
        
bank={"Amit":[123456789111,9969608452,12045.00,1452],"Ansh":[154287964511,8874596213,15847.00,1785],"Arya":[124578963100,8097506542,7000.00,1986],"Nitya":[174854127845,9969607456,178450.00,9541],"Anjana":[118874561402,9874561230,85000.00,8945],"Arjun":[145276324101,7412311000,100000.00,5412]}

while(True):
    i=bank.keys()
    name=input('Enter Name: ')
    if name in i:
        i=3
        while(i>0):
            pin=int(input('Enter your Account PIN: '))
            if pin==bank[name][3]:
                x= atm()
                while(True):
                    print(' 1 For Account Info \n 2 For PIN Change \n 3 For Balance Inquiry \n 4 For Deposit \n 5 For Withdrawal \n 6 For Exit ')
                  
                    choice=int(input('Choose  option number  : '))
                    if choice==1:
                        x.accdetails()
                    elif choice==2:
                        x.pin()
                    elif choice==3:
                        x.balance()
                    elif choice==4:
                        x.deposit()
                    elif choice==5:
                        x.withdrawal()
                    elif choice==6:
                        print(" Thankyou for transaction!")
                        break
                    else:
                        print('Wrong Option , Please select Valid Input ')
                        break
                    
            else:
                i=i-1
                print("enter correct PIN", i, " Chances Remaining" )
            break
        
        if i==0:
            del bank[name]
            print("Account Blocked \n Contact  nearest Bank for further queries")
            print(" Bank number: 022-54278145 \n email:bank@123.bank.in")
        

    continue
# Out:
# Welcome!
# Enter Name: Amit
# Enter your Account PIN: 1452
#  1 For Account Info
#  2 For PIN Change
#  3 For Balance Inquiry
#  4 For Deposit
#  5 For Withdrawal
#  6 For Exit
# Choose  option number  : 6
#  Thankyou for transaction!
# Enter Name: Amit
# Enter your Account PIN: 1452
#  1 For Account Info
#  2 For PIN Change
#  3 For Balance Inquiry
#  4 For Deposit
#  5 For Withdrawal
#  6 For Exit
# Choose  option number  : 2
# Enter previous PIN: 1452
# Enter new PIN: 1400
# Confirm new PIN:1400
#  1 For Account Info
#  2 For PIN Change
#  3 For Balance Inquiry
#  4 For Deposit
#  5 For Withdrawal
#  6 For Exit
# Choose  option number  : 6
#  Thankyou for transaction!
